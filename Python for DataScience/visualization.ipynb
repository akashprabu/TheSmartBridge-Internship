# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'g')
plt.xlabel("this is x axis")
plt.ylabel("this is y axis")
plt.title("this is my title")
# Out:
# Text(0.5, 1.0, 'this is my title')

# %%
plt.scatter(x,y,color = "red",marker = "*")
plt.xlabel("this is x axis")
plt.ylabel("this is y axis")
plt.title("this is my title")
# Out:
# Text(0.5, 1.0, 'this is my title')

# %%
plt.subplot(3,3,1)
plt.plot(x,y,'g')
plt.xlabel("this is x axis")
plt.ylabel("this is y axis")
plt.title("this is my title")
plt.subplot(3,3,3)
plt.scatter(x,y,color = "red",marker = "*")
plt.xlabel("this is x axis")
plt.ylabel("this is y axis")
plt.title("this is my title")
# Out:
# Text(0.5, 1.0, 'this is my title')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes.plot(x,y,'b',label = "bigplot")
axes.legend(loc = "upper right")
axes.set_xlabel("xaxiss")
axes.set_ylabel("yaxiss")
axes2.plot(x,y,'red',label = "smallerplot")
axes2.scatter(y,x,color = 'red')
axes2.legend(loc  = "center")

# %%
plt.bar(x,y,color = "green")
plt.xlabel("xaxis")
plt.ylabel("yaxis")
# Out:
# Text(0, 0.5, 'yaxis')

# %%
labels = ["php","python","jaa","c"]
number = [75,70,80,60]
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)
ax2 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)
ax.pie(number,labels =labels, autopct = '%0.1f%%',colors = ["orange","blue","pink","yellow"])
ax1.plot(x,y)
ax2.bar(x,y)
ax3.scatter(x,y)

ax.legend(number,loc = "upper left")

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('iris')

# %%
tips
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = "total_bill",y = "tip" ,data = tips )

# %%
plt.scatter(tips["total_bill"],tips["tip"],color = 'blue')

# %%
sns.lineplot(x="size",y="tip",data = tips)

# %%
sns.distplot(tips['tip'])

# %%
sns.barplot(x = "time",y="tip",data =  tips)

# %%
sns.boxplot(x = "size",y="tip", data = tips)

# %% [raw]
# tips.describe()

# %%
1 - 1.0 ,2.0,3.0,2.0,6,2
2
3
4
5
6
# Out:
# 6

# %%
sns.catplot(x="smoker",y="tip",data = tips)

# %%
sns.catplot(x="day",y="tip",hue = 'sex',data = tips)

# %%
sns.pairplot(tips,hue = 'time')

# %%
tips.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [raw]
# -1 to 1
# threshold 0.5
# value >0.5 - it is higly possitively corelated - directproportionality
# valuues <0.5 - it is partially corelated
# value >-0.5  - its  is partially negatively corelated
# value <-0.5 - it is negatively highly corelated -   inverse proportionalyity

# %%
sns.heatmap(tips.corr(),annot = True)

# %%
tips.to_csv("newtips.csv")
